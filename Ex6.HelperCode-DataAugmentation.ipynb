# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 6th exercise: <font color="#C70039">Perform data augmentation for sample solution in exercise 6</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Student: Tim Köhne
# * Matriculation number: 11147022
# * Date: 02.11.2025
#
# <img src="http://ai.stanford.edu/blog/assets/img/posts/2020-04-20-data-augmentation/thumbnail.png" style="float: center;" width="450">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# ---------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# This notebook allows you for performing data augmentation and saving the augmented images back to disc.
#
# -------------------------------------------------------------------------------------------------------------

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import os
# Out:
# 2025-11-03 21:05:31.190884: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#datagen = ImageDataGenerator(shear_range=0.2, zoom_range=0.2, rotation_range=90) 
datagen = ImageDataGenerator(
                    rotation_range=90,
                    horizontal_flip=True,
                    vertical_flip=True,
                    width_shift_range=45.0,
                    height_shift_range=45.0) 

# original image(s)
# make sure the /augmented/ folder is not there too - adapt code otherwise
img_folder  = "./data/heisenberg_heisenberg"
image_names=os.listdir(img_folder)
image_names = [image_name for image_name in image_names if image_name.endswith(".jpg")]

print('image_names:',image_names)

for filename in image_names:
    print(filename)
    img = load_img("./data/heisenberg_heisenberg/" + filename)  
    x = img_to_array(img) 
    # Reshape the input image 
    x = x.reshape((1, ) + x.shape)  
    i = 0
    
    # set n to the number of augmented images you want
    n = 50
    save_dir = f'./data/augmented/{filename[:-4]}/'
    os.makedirs(save_dir)
    # generate n new augmented images and store them in an /augmented/ folder that exists 
    for batch in datagen.flow(x, batch_size = 1, save_to_dir = save_dir, save_format ='jpg', seed=1):
        i += 1
        if i > n: 
            break
# Out:
# image_names: ['walter-white-original.jpg', 'gernot-heisenberg-original.jpg']
# walter-white-original.jpg
# gernot-heisenberg-original.jpg
