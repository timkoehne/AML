# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 2nd exercise: <font color="#C70039">Work with Boxplots for anomaly detection</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Student: Tim Köhne
# * Matriculation number: 11147022
# * Date: 28.10.2025
#
# <img src="https://r-graph-gallery.com/img/other/boxplot_explanation.png" style="float: center;" width="800">
# <img src="https://i2.wp.com/upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/550px-Boxplot_vs_PDF.svg.png?w=578" style="float: center;" width="800">
#
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too
# * This applies to all exercises throughout this course.
#
# ---------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# This notebook allows you for using boxplots to detect anomalies. Try to interpret the boxplot.
#
# -------------------------------------------------------------------------------------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
# 4. take the three data sets from exercize 1 and create a boxplot for each of them
# 5. interpret the visual results and describe them
# 6. how can you test your data for being normally distributed?
# -----------------------------------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randn
np.random.seed(1)

# %%
# multiply and add by random numbers to get some real values
# randn generates samples from the normal distribution (important - see below)
random_data = np.random.randn(50000)  * 20 + 20

# %%
sns.boxplot(data=random_data)
plt.show()

# %% [markdown]
# # Load Datasets

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "burnoutminer/heights-and-weights-dataset",
   "SOCR-HeightWeight.csv",
)

dataset_0 = df["Height(Inches)"]
dataset_1 = df["Weight(Pounds)"]


df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
     "andrewmvd/heart-failure-clinical-data",
     "heart_failure_clinical_records_dataset.csv"
)

dataset_2 = df["creatinine_phosphokinase"]

# %% [markdown]
# # Task 4: Create Boxplots for the data from Exercise 1

# %%
sns.boxplot(data=dataset_0, orient="h")
plt.show()
sns.boxplot(data=dataset_1, orient="h")
plt.show()
sns.boxplot(data=dataset_2, orient="h")
plt.show()

# %% [markdown]
# # Task 5: Interpret the Boxplots
# The median is the center-line. The box shows the ICR (interquartile range) from Q1 at 25% (lower quartile) to Q3 at 75% (upper quartile) of the data.
# The whiskers seperates normal from anormal data. They are calculated as Q1 - 1.5\*IQR and Q3 + 1.5\*IQR.

# %% [markdown]
# # Task 6: Testing data for being normally distributed
# - Easy and decent: looking at a histogram of the data.
# - Statistical test like Shapiro-Wilk test.
